# %%
import json
import os
import random
import warnings

import numpy as np
import pandas as pd
import torch
from tqdm import tqdm, trange

warnings.filterwarnings("ignore")

# Set up seeds
seed = 42
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
random.seed(seed)


def read_jsonl_file(jsonl_path):
    with open(jsonl_path, "r") as f:
        for line in f:
            yield json.loads(line)

# %%
path = "defects4j.jsonl"


# convert to csv
data = []
for d in read_jsonl_file(path):
    data.append(d)


df = pd.DataFrame(data)
#bug_id,func_before,func_after
df.rename(columns={"buggy_code": "func_before", "fixed_code": "func_after"}, inplace=True)

df.to_csv("defects4j.csv", index=False)

# %%
df
# Out:
#              bug_id                                        func_before  \
# 0       Compress-35      public static boolean verifyCheckSum(byte[...
# 1    JacksonCore-21      public JsonToken nextToken() throws IOExce...
# 2            Lang-5      public static Locale toLocale(final String...
# 3          Codec-17      public static String newStringIso8859_1(fi...
# 4       Compress-12      public TarArchiveEntry getNextTarEntry() t...
# ..              ...                                                ...
# 462     Closure-111          protected JSType caseTopType(JSType to...
# 463      Closure-12    private boolean hasExceptionHandler(Node cfg...
# 464        Jsoup-70      static boolean preserveWhitespace(Node nod...
# 465      Closure-66    public void visit(NodeTraversal t, Node n, N...
# 466      Closure-23    private Node tryFoldArrayAccess(Node n, Node...
#
#                                             func_after
# 0        public static boolean verifyCheckSum(byte[...
# ...
